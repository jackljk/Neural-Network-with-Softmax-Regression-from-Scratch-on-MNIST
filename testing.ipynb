# %%
from util import *
import numpy as np

# %%
# Load the data
x_train, y_train, x_valid, y_valid, x_test, y_test = load_data(path="./data/")

# Load the configuration from the corresponding yaml file. Specify the file path and name
config = load_config("configs/config_9.yaml")
# Out:
# Loading MNIST data from ./data/mnist.pkl
# Done.

# %%
from neuralnet import Neuralnetwork
from train import train

# %%
model = Neuralnetwork(config)
model = train(model, x_train, y_train, x_valid, y_valid, config)
# Out:
# Epoch:  1  Loss:  1.534946084666668  Accuracy:  0.6431666666666667
# Validation Loss:  0.7472614324592279  Validation Accuracy:  0.8148333333333333
# Epoch:  2  Loss:  0.555897016136143  Accuracy:  0.8559791666666666
# Validation Loss:  0.4712705062381112  Validation Accuracy:  0.8699166666666667
# Epoch:  3  Loss:  0.4129767724331623  Accuracy:  0.8872083333333334
# Validation Loss:  0.40042052129099054  Validation Accuracy:  0.8843333333333333
# Epoch:  4  Loss:  0.36440350774072083  Accuracy:  0.898125
# Validation Loss:  0.36816807349292563  Validation Accuracy:  0.89275
# Epoch:  5  Loss:  0.3399690098570495  Accuracy:  0.904625
# Validation Loss:  0.34898965058756776  Validation Accuracy:  0.8968333333333334
# Epoch:  6  Loss:  0.32435318553095677  Accuracy:  0.9079791666666667
# Validation Loss:  0.3357381817665971  Validation Accuracy:  0.90025
# Epoch:  7  Loss:  0.31332353912105954  Accuracy:  0.9115416666666667
# ...

# %%
from train import modelTest

# %%
modelTest(model, x_test, y_test)
# Out:
# (0.9756, 0.07861372151648864)
